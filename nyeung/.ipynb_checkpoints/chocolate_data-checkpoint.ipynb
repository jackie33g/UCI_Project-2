# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts
from sqlalchemy import create_engine

# %%
choco = "data/chocolate.csv"
choco_df = pd.read_csv(choco) 
choco_df.head()
# Out:
#    ID   ref   company company_location  review_date country_of_bean_origin  \
# 0   0  2454      5150            U.S.A         2019             Madagascar
# 1   1  2458      5150            U.S.A         2019     Dominican republic
# 2   2  2454      5150            U.S.A         2019               Tanzania
# 3   3   797  A. Morin           France         2012                   Peru
# 4   4   797  A. Morin           France         2012                Bolivia
#
#   specific_bean_origin_or_bar_name  cocoa_percent  rating  \
# 0           Bejofo Estate, batch 1           76.0    3.75
# 1                  Zorzal, batch 1           76.0    3.50
# 2            Kokoa Kamili, batch 1           76.0    3.25
# 3                             Peru           63.0    3.75
# 4                          Bolivia           70.0    3.50
#
#    counts_of_ingredients  ...       cocoa_butter          vanilla  \
# 0                      3  ...  have_cocoa_butter  have_not_vanila
# 1                      3  ...  have_cocoa_butter  have_not_vanila
# 2                      3  ...  have_cocoa_butter  have_not_vanila
# 3                      4  ...  have_cocoa_butter  have_not_vanila
# 4                      4  ...  have_cocoa_butter  have_not_vanila
#
#             lecithin           salt       sugar  \
# 0  have_not_lecithin  have_not_salt  have_sugar
# 1  have_not_lecithin  have_not_salt  have_sugar
# 2  have_not_lecithin  have_not_salt  have_sugar
# 3      have_lecithin  have_not_salt  have_sugar
# 4      have_lecithin  have_not_salt  have_sugar
#
#             sweetener_without_sugar first_taste second_taste third_taste  \
# 0  have_not_sweetener_without_sugar       cocoa   blackberry   full body
# 1  have_not_sweetener_without_sugar       cocoa      vegetal      savory
# 2  have_not_sweetener_without_sugar  rich cocoa        fatty      bready
# 3  have_not_sweetener_without_sugar      fruity        melon      roasty
# 4  have_not_sweetener_without_sugar     vegetal        nutty         NaN
#
#   fourth_taste
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 21 columns]

# %%
choco_df_clean = choco_df[['ID','company_location','review_date','country_of_bean_origin','cocoa_percent','rating']]
choco_df_clean.head()
# Out:
#    ID company_location  review_date country_of_bean_origin  cocoa_percent  \
# 0   0            U.S.A         2019             Madagascar           76.0
# 1   1            U.S.A         2019     Dominican republic           76.0
# 2   2            U.S.A         2019               Tanzania           76.0
# 3   3           France         2012                   Peru           63.0
# 4   4           France         2012                Bolivia           70.0
#
#    rating
# 0    3.75
# 1    3.50
# 2    3.25
# 3    3.75
# 4    3.50

# %%
choco_year = choco_df_clean.loc[(choco_df_clean['review_date'] >=2015) & (choco_df_clean['review_date']<=2019)]
choco_year.head()
# Out:
#     ID company_location  review_date country_of_bean_origin  cocoa_percent  \
# 0    0            U.S.A         2019             Madagascar           76.0
# 1    1            U.S.A         2019     Dominican republic           76.0
# 2    2            U.S.A         2019               Tanzania           76.0
# 21  21           France         2015                   Togo           70.0
# 22  22           France         2015                   Peru           70.0
#
#     rating
# 0     3.75
# 1     3.50
# 2     3.25
# 21    3.50
# 22    3.50

# %%
choco_year.describe()
# Out:
#                 ID  review_date  cocoa_percent       rating
# count  1017.000000  1017.000000    1017.000000  1017.000000
# mean   1117.004916  2016.842675      71.744346     3.221337
# std     642.647527     1.509428       4.378391     0.390540
# min       0.000000  2015.000000      57.000000     2.000000
# 25%     566.000000  2015.000000      70.000000     3.000000
# 50%    1114.000000  2017.000000      70.000000     3.250000
# 75%    1684.000000  2018.000000      74.000000     3.500000
# max    2223.000000  2019.000000     100.000000     4.000000

# %%
choco_year_new= choco_year[choco_year.country_of_bean_origin !='Blend']
choco_year_new.head()
# Out:
#     ID company_location  review_date country_of_bean_origin  cocoa_percent  \
# 0    0            U.S.A         2019             Madagascar           76.0
# 1    1            U.S.A         2019     Dominican republic           76.0
# 2    2            U.S.A         2019               Tanzania           76.0
# 21  21           France         2015                   Togo           70.0
# 22  22           France         2015                   Peru           70.0
#
#     rating
# 0     3.75
# 1     3.50
# 2     3.25
# 21    3.50
# 22    3.50

# %%
choco_year_new.describe()
# Out:
#                 ID  review_date  cocoa_percent      rating
# count   997.000000   997.000000     997.000000  997.000000
# mean   1116.202608  2016.845537      71.764293    3.224273
# std     639.982790     1.511739       4.344492    0.386309
# min       0.000000  2015.000000      57.000000    2.000000
# 25%     567.000000  2015.000000      70.000000    3.000000
# 50%    1114.000000  2017.000000      70.000000    3.250000
# 75%    1678.000000  2018.000000      74.000000    3.500000
# max    2222.000000  2019.000000     100.000000    4.000000

# %%
choco_year_new1 = choco_year_new.replace('U.s.a.','U.S.A')

# %%
print(choco_year_new1.loc[[1290]])
# Out:
#         ID company_location  review_date country_of_bean_origin  \
# 1290  1290            U.S.A         2019                  U.S.A
#
#       cocoa_percent  rating
# 1290           70.0     3.5

# %%
choco_year_new1 = choco_year_new1.replace('U.k.','U.K.')

# %%
print(choco_year_new1.loc[[567]])
# Out:
#       ID company_location  review_date country_of_bean_origin  cocoa_percent  \
# 567  567             U.K.         2015               Trinidad           70.0
#
#      rating
# 567     3.0

# %%
choco_year_new1 = choco_year_new1.replace('U.a.e.','U.A.E.')

# %%
choco_year_new1 = choco_year_new1.replace('Sao tome','Sao tome & principe')

# %%
print(choco_year_new1.loc[[653]])
# Out:
#       ID     company_location  review_date country_of_bean_origin  \
# 653  653  Sao tome & principe         2019    Sao tome & principe
#
#      cocoa_percent  rating
# 653           75.0     3.0

# %%
id_df = choco_year_new1[['ID','review_date']]
id_df.head()
# Out:
#     ID  review_date
# 0    0         2019
# 1    1         2019
# 2    2         2019
# 21  21         2015
# 22  22         2015

# %%
dependency_chart = choco_year_new1[['ID','company_location','country_of_bean_origin']]
dependency_chart.head()
# Out:
#     ID company_location country_of_bean_origin
# 0    0            U.S.A             Madagascar
# 1    1            U.S.A     Dominican republic
# 2    2            U.S.A               Tanzania
# 21  21           France                   Togo
# 22  22           France                   Peru

# %%
scatterplot_chart = choco_year_new1[['ID','company_location','country_of_bean_origin','rating']]
scatterplot_chart.head()
# Out:
#     ID company_location country_of_bean_origin  rating
# 0    0            U.S.A             Madagascar    3.75
# 1    1            U.S.A     Dominican republic    3.50
# 2    2            U.S.A               Tanzania    3.25
# 21  21           France                   Togo    3.50
# 22  22           France                   Peru    3.50

# %%
donut_chart = choco_year_new1[['ID','company_location','cocoa_percent','rating']]
donut_chart.head()
# Out:
#     ID company_location  cocoa_percent  rating
# 0    0            U.S.A           76.0    3.75
# 1    1            U.S.A           76.0    3.50
# 2    2            U.S.A           76.0    3.25
# 21  21           France           70.0    3.50
# 22  22           France           70.0    3.50

# %%
rds_connection_string = "postgres:postgres@localhost:5432/Chocolate_DB"
engine = create_engine(f'postgresql+psycopg2://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['id_df', 'dependency_chart', 'scatterplot_chart', 'donut_chart']

# %%
id_df.to_sql(name='id_df', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_id_df"
# DETAIL:  Key ("ID")=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-53-f601919279e5> in <module>
# ----> 1 id_df.to_sql(name='id_df', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2610             chunksize=chunksize,
#    2611             dtype=dtype,
# -> 2612             method=method,
#    2613         )
#    2614
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_id_df"
# DETAIL:  Key ("ID")=(0) already exists.
#
# [SQL: INSERT INTO id_df ("ID", review_date) VALUES (%(ID)s, %(review_date)s)]
# [parameters: ({'ID': 0, 'review_date': 2019}, {'ID': 1, 'review_date': 2019}, {'ID': 2, 'review_date': 2019}, {'ID': 21, 'review_date': 2015}, {'ID': 22, 'review_date': 2015}, {'ID': 23, 'review_date': 2015}, {'ID': 24, 'review_date': 2015}, {'ID': 25, 'review_date': 2016}  ... displaying 10 of 997 total bound parameter sets ...  {'ID': 2221, 'review_date': 2018}, {'ID': 2222, 'review_date': 2018})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)

# %%
pd.read_sql_query('select * from id_df', con=engine).head()
# Out:
#    ID  review_date
# 0   0         2019
# 1   1         2019
# 2   2         2019
# 3  21         2015
# 4  22         2015

# %%
dependency_chart.to_sql(name='dependency_chart', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from dependency_chart', con=engine).head()
# Out:
#    ID company_location country_of_bean_origin
# 0   0            U.S.A             Madagascar
# 1   1            U.S.A     Dominican republic
# 2   2            U.S.A               Tanzania
# 3  21           France                   Togo
# 4  22           France                   Peru

# %%
scatterplot_chart.to_sql(name='scatterplot_chart', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from scatterplot_chart', con=engine).head()
# Out:
#    ID company_location country_of_bean_origin  rating
# 0   0            U.S.A             Madagascar    3.75
# 1   1            U.S.A     Dominican republic    3.50
# 2   2            U.S.A               Tanzania    3.25
# 3  21           France                   Togo    3.50
# 4  22           France                   Peru    3.50

# %%
donut_chart.to_sql(name='donut_chart', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_donut_chart"
# DETAIL:  Key ("ID")=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-60-bef5db105128> in <module>
# ----> 1 donut_chart.to_sql(name='donut_chart', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2610             chunksize=chunksize,
#    2611             dtype=dtype,
# -> 2612             method=method,
#    2613         )
#    2614
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_donut_chart"
# DETAIL:  Key ("ID")=(0) already exists.
#
# [SQL: INSERT INTO donut_chart ("ID", company_location, cocoa_percent, rating) VALUES (%(ID)s, %(company_location)s, %(cocoa_percent)s, %(rating)s)]
# [parameters: ({'ID': 0, 'company_location': 'U.S.A', 'cocoa_percent': 76.0, 'rating': 3.75}, {'ID': 1, 'company_location': 'U.S.A', 'cocoa_percent': 76.0, 'rating': 3.5}, {'ID': 2, 'company_location': 'U.S.A', 'cocoa_percent': 76.0, 'rating': 3.25}, {'ID': 21, 'company_location': 'France', 'cocoa_percent': 70.0, 'rating': 3.5}, {'ID': 22, 'company_location': 'France', 'cocoa_percent': 70.0, 'rating': 3.5}, {'ID': 23, 'company_location': 'France', 'cocoa_percent': 70.0, 'rating': 3.0}, {'ID': 24, 'company_location': 'France', 'cocoa_percent': 70.0, 'rating': 2.75}, {'ID': 25, 'company_location': 'France', 'cocoa_percent': 63.0, 'rating': 3.75}  ... displaying 10 of 997 total bound parameter sets ...  {'ID': 2221, 'company_location': 'Austria', 'cocoa_percent': 72.0, 'rating': 3.5}, {'ID': 2222, 'company_location': 'Austria', 'cocoa_percent': 70.0, 'rating': 3.25})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
